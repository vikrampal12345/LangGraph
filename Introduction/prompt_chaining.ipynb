# %%
from langgraph.graph import StateGraph, START, END
from langchain_google_genai import ChatGoogleGenerativeAI
from typing import TypedDict
from dotenv import load_dotenv
import os

# %%
load_dotenv()
model = ChatGoogleGenerativeAI(
    model="gemini-3.8-flash",
    temperature=0,
    google_api_key=os.getenv("GEMINI_API_KEY"))

# %%
class BlogState(TypedDict):

    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:

    # fetch title
    title = state['title']

    # call llm gen outline
    prompt = f'Generate a detailed outline for a blog on the topic - {title}'
    outline = model.invoke(prompt).content

    # update state
    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState) -> BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title - {title} using the following outline \n {outline}'

    content = model.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

# nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

# edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
intial_state = {'title' : 'Rise of AI in India'}

final_state = workflow.invoke(intial_state)

print(final_state)
# Out:
# {'title': 'Rise of AI in India', 'outline': [{'type': 'text', 'text': 'Here is a comprehensive and detailed outline for a blog post titled **"The Rise of AI in India: From IT Back-Office to Global Innovation Hub."**\n\n---\n\n# Blog Outline: The Rise of AI in India\n\n## **Catchy Title Ideas**\n* *The Silicon Subcontinent: Inside India’s Rapid AI Revolution*\n* *From Code to Cognition: How AI is Reshaping Modern India*\n* *The Rise of AI in India: Building the Future at Population Scale*\n* *Sovereign Intelligence: How India is Carving its Own Path in the Global AI Race*\n\n---\n\n## **1. Introduction**\n* **The Hook:** Contrast India’s historical reputation as the world\'s "IT back-office" with its new reality as a hotbed for cutting-edge Artificial Intelligence.\n* **The Context:** Briefly highlight major milestones (e.g., the launch of the **IndiaAI Mission**, homegrown LLMs like Krutrim and Sarvam AI, and massive investments from global giants like Microsoft, Google, and NVIDIA).\n* **Thesis Statement:** India is uniquely positioned to lead the global AI revolution by combining massive demographic scale, a robust Digital Public Infrastructure (DPI), and a focus on frugal, high-impact innovation.\n\n---\n\n## **2. The Catalyst: Why is the AI Boom Happening Now?**\n* **The Demographic & Data Advantage:** \n  * Over 800+ million internet users generating petabytes of diverse data daily.\n  * The world\'s largest pool of young STEM graduates.\n* **The "India Stack" Foundation:** \n  * How UPI, Aadhaar, and DigiLocker created a digitized society ready for AI integration.\n* **Affordable High-Speed Connectivity:** \n  * The role of ultra-cheap 4G/5G data in democratizing access to AI tools across Tier-2, Tier-3 cities, and rural areas.\n\n---\n\n## **3. Government as an Enabler: Policy, Compute, and "Sovereign AI"**\n* **The ₹10,300+ Crore ($1.2B) IndiaAI Mission:**\n  * Subsidizing compute capacity (procuring 10,000+ GPUs) to support startups and researchers.\n* **Focus on "Sovereign AI":**\n  * The push to develop domestic foundational models to avoid dependence on Western or Chinese technology and protect national data sovereignty.\n* **Regulatory Framework:**\n  * Balancing innovation with safety: The Digital Personal Data Protection (DPDP) Act and the government\'s light-touch regulatory approach to AI.\n\n---\n\n## **4. Transforming Key Sectors: AI for 1.4 Billion People**\n*Focus on how India uses AI not just for enterprise productivity, but for social impact:*\n* **A. Agriculture (Agritech):**\n  * Predictive analytics for weather, pest control, and soil health (e.g., AI-driven crop insurance assessments).\n* **B. Healthcare:**\n  * Bridging the doctor-to-patient deficit: AI diagnostic tools for tuberculosis, diabetic retinopathy, and cancer in remote areas (e.g., Qure.ai).\n* **C. Education:**\n  * Vernacular tutoring bots, adaptive learning platforms, and grading automation.\n* **D. Governance & Citizen Services:**\n  * Conversational AI platforms like **Jugalbandi**, allowing rural citizens to access government welfare schemes in their local dialects via WhatsApp.\n\n---\n\n## **5. India’s Unique Frontier: Multilingual AI (The Language Barrier)**\n* **The Challenge:** India has 22 scheduled languages and hundreds of dialects; traditional LLMs (GPT-4) are heavily English-centric.\n* **The Solution:** \n  * **Project Bhashini:** The government’s open-source initiative to build language translation datasets.\n  * **Indic LLMs:** The emergence of models trained natively on Indian languages (e.g., Sarvam AI, Hanooman, Krutrim).\n  * Voice-first interfaces: Why the future of Indian AI is spoken, not typed.\n\n---\n\n## **6. The Thriving Startup & Big Tech Ecosystem**\n* **Homegrown Startups:** \n  * Rise of deep-tech unicorns and AI-first startups across enterprise SaaS, healthcare, and finance.\n* **Global Tech Bets:**\n  * Why NVIDIA, Google, and Microsoft are partnering with Indian conglomerates (Reliance Jio, Tata Group ...

# %%
final_state['outline']
# Out:
# [{'type': 'text',
#   'text': 'Here is a comprehensive and detailed outline for a blog post titled **"The Rise of AI in India: From IT Back-Office to Global Innovation Hub."**\n\n---\n\n# Blog Outline: The Rise of AI in India\n\n## **Catchy Title Ideas**\n* *The Silicon Subcontinent: Inside India’s Rapid AI Revolution*\n* *From Code to Cognition: How AI is Reshaping Modern India*\n* *The Rise of AI in India: Building the Future at Population Scale*\n* *Sovereign Intelligence: How India is Carving its Own Path in the Global AI Race*\n\n---\n\n## **1. Introduction**\n* **The Hook:** Contrast India’s historical reputation as the world\'s "IT back-office" with its new reality as a hotbed for cutting-edge Artificial Intelligence.\n* **The Context:** Briefly highlight major milestones (e.g., the launch of the **IndiaAI Mission**, homegrown LLMs like Krutrim and Sarvam AI, and massive investments from global giants like Microsoft, Google, and NVIDIA).\n* **Thesis Statement:** India is uniquely positioned to lead the global AI revolution by combining massive demographic scale, a robust Digital Public Infrastructure (DPI), and a focus on frugal, high-impact innovation.\n\n---\n\n## **2. The Catalyst: Why is the AI Boom Happening Now?**\n* **The Demographic & Data Advantage:** \n  * Over 800+ million internet users generating petabytes of diverse data daily.\n  * The world\'s largest pool of young STEM graduates.\n* **The "India Stack" Foundation:** \n  * How UPI, Aadhaar, and DigiLocker created a digitized society ready for AI integration.\n* **Affordable High-Speed Connectivity:** \n  * The role of ultra-cheap 4G/5G data in democratizing access to AI tools across Tier-2, Tier-3 cities, and rural areas.\n\n---\n\n## **3. Government as an Enabler: Policy, Compute, and "Sovereign AI"**\n* **The ₹10,300+ Crore ($1.2B) IndiaAI Mission:**\n  * Subsidizing compute capacity (procuring 10,000+ GPUs) to support startups and researchers.\n* **Focus on "Sovereign AI":**\n  * The push to develop domestic foundational models to avoid dependence on Western or Chinese technology and protect national data sovereignty.\n* **Regulatory Framework:**\n  * Balancing innovation with safety: The Digital Personal Data Protection (DPDP) Act and the government\'s light-touch regulatory approach to AI.\n\n---\n\n## **4. Transforming Key Sectors: AI for 1.4 Billion People**\n*Focus on how India uses AI not just for enterprise productivity, but for social impact:*\n* **A. Agriculture (Agritech):**\n  * Predictive analytics for weather, pest control, and soil health (e.g., AI-driven crop insurance assessments).\n* **B. Healthcare:**\n  * Bridging the doctor-to-patient deficit: AI diagnostic tools for tuberculosis, diabetic retinopathy, and cancer in remote areas (e.g., Qure.ai).\n* **C. Education:**\n  * Vernacular tutoring bots, adaptive learning platforms, and grading automation.\n* **D. Governance & Citizen Services:**\n  * Conversational AI platforms like **Jugalbandi**, allowing rural citizens to access government welfare schemes in their local dialects via WhatsApp.\n\n---\n\n## **5. India’s Unique Frontier: Multilingual AI (The Language Barrier)**\n* **The Challenge:** India has 22 scheduled languages and hundreds of dialects; traditional LLMs (GPT-4) are heavily English-centric.\n* **The Solution:** \n  * **Project Bhashini:** The government’s open-source initiative to build language translation datasets.\n  * **Indic LLMs:** The emergence of models trained natively on Indian languages (e.g., Sarvam AI, Hanooman, Krutrim).\n  * Voice-first interfaces: Why the future of Indian AI is spoken, not typed.\n\n---\n\n## **6. The Thriving Startup & Big Tech Ecosystem**\n* **Homegrown Startups:** \n  * Rise of deep-tech unicorns and AI-first startups across enterprise SaaS, healthcare, and finance.\n* **Global Tech Bets:**\n  * Why NVIDIA, Google, and Microsoft are partnering with Indian conglomerates (Reliance Jio, Tata Group) to build sovereign cloud infrastructure.\n  * Global Capab ...
#   'extras': {'signature': '...'}}]

# %%
print(final_state['content'])
# Out:
# [{'type': 'text', 'text': '# The Silicon Subcontinent: Inside India’s Rapid AI Revolution\n*From the World’s IT Back-Office to a Population-Scale Global AI Powerhouse*\n\n---\n\n## 1. Introduction: A Paradigm Shift in Indian Tech\n\nFor nearly four decades, the global technology narrative cast India in a predictable role: the world’s digital back-office. From solving the Y2K bug to maintaining enterprise software and managing vast business process outsourcing (BPO) networks, India was where the world went for scalable, cost-effective engineering muscle. \n\nThat narrative is officially obsolete.\n\nToday, India is undergoing a tectonic transformation—shifting from low-margin code maintenance to high-value cognitive innovation. Walk into the tech hubs of Bengaluru, Hyderabad, or Pune, and the conversation is no longer about billable hours or service-level agreements. It is about **Sovereign Large Language Models (LLMs)**, **population-scale inference**, and **AI-driven societal transformation**.\n\n```\n   1990s – 2010s                    2020s & Beyond\n┌─────────────────────────┐      ┌─────────────────────────┐\n│  THE IT BACK-OFFICE     │  ──► │ GLOBAL INNOVATION HUB   │\n│  • Cost arbitrage       │      │ • Sovereign AI models   │\n│  • Maintenance & BPO    │      │ • Population-scale DPI  │\n│  • Western IP execution │      │ • High-impact deep tech │\n└─────────────────────────┘      └─────────────────────────┘\n```\n\nThe momentum is unmistakable:\n* The Indian Union Cabinet approved the comprehensive **₹10,372 crore (~$1.2 billion) IndiaAI Mission**.\n* Domestic foundation model builders such as **Sarvam AI** and **Krutrim** have raised massive capital rounds to build for local realities.\n* Global tech leaders—from NVIDIA’s Jensen Huang to Microsoft’s Satya Nadella—frequently visit the subcontinent, forging multi-billion-dollar infrastructure alliances with Indian conglomerates like Reliance and Tata.\n\n**The Thesis:** India is uniquely positioned to lead the next era of artificial intelligence. By combining demographic scale, a battle-tested Digital Public Infrastructure (DPI), and an ethos of frugal, high-impact innovation, India is not merely adopting AI—it is defining how AI can serve the next billion users.\n\n---\n\n## 2. The Catalyst: Why the AI Boom Is Happening Now\n\nTechnological revolutions do not occur in a vacuum; they require a critical mass of infrastructure, data, and human capital. India has reached this inflection point through three converging forces:\n\n```\n                  ┌───────────────────────────────┐\n                  │   INDIA\'S AI CONVERGENCE      │\n                  └──────────────┬────────────────┘\n                                 │\n         ┌───────────────────────┼───────────────────────┐\n         ▼                       ▼                       ▼\n┌──────────────────┐   ┌──────────────────┐   ┌──────────────────┐\n│ DEMOGRAPHIC DATA │   │   INDIA STACK    │   │ HYPER-AFFORDABLE │\n│    ADVANTAGE     │   │      (DPI)       │   │   CONNECTIVITY   │\n│ • 800M+ users    │   │ • UPI, Aadhaar   │   │ • Lowest 1GB cost│\n│ • Diverse inputs │   │ • DigiLocker     │   │ • 5G rollout     │\n│ • STEM talent    │   │ • Structured API │   │ • Tier-2/3 access│\n└──────────────────┘   └──────────────────┘   └──────────────────┘\n```\n\n### The Demographic and Data Advantage\nIndia boasts an active internet user base exceeding **800 million**, generating petabytes of diverse, multimodal data every day across commerce, entertainment, voice, and financial services. More crucially, India produces over **1.5 million engineering and STEM graduates annually**—the largest pipeline of technical talent on the planet. As global focus shifts from classical coding to machine learning architecture, this vast workforce is rapidly upskilling.\n\n### The "India Stack" Foundation\nArtificial Intelligence requires structured, verifiable, and secure data rails to deliver real-world utility. India spent the las ...
